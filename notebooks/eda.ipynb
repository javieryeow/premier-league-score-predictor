# %%
import pandas as pd
df = pd.read_csv("../data/PremierLeague.csv")
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12160 entries, 0 to 12159
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MatchID                 12160 non-null  object
#  1   Season                  12160 non-null  object
#  2   MatchWeek               12160 non-null  int64
#  3   Date                    12160 non-null  object
#  4   Time                    2280 non-null   object
#  5   HomeTeam                12160 non-null  object
#  6   AwayTeam                12160 non-null  object
#  7   FullTimeHomeTeamGoals   12160 non-null  int64
#  8   FullTimeAwayTeamGoals   12160 non-null  int64
#  9   FullTimeResult          12160 non-null  object
#  10  HalfTimeHomeTeamGoals   11400 non-null  float64
#  11  HalfTimeAwayTeamGoals   11400 non-null  float64
#  12  HalfTimeResult          11400 non-null  object
#  13  Referee                 9500 non-null   object
#  14  HomeTeamShots           9500 non-null   float64
#  15  AwayTeamShots           9500 non-null   float64
#  16  HomeTeamShotsOnTarget   9500 non-null   float64
#  17  AwayTeamShotsOnTarget   9500 non-null   float64
#  18  HomeTeamCorners         9500 non-null   float64
#  19  AwayTeamCorners         9500 non-null   float64
#  20  HomeTeamFouls           9500 non-null   float64
#  21  AwayTeamFouls           9500 non-null   float64
#  22  HomeTeamYellowCards     9500 non-null   float64
#  23  AwayTeamYellowCards     9500 non-null   float64
#  24  HomeTeamRedCards        9500 non-null   float64
#  25  AwayTeamRedCards        9500 non-null   float64
#  26  B365HomeTeam            8740 non-null   float64
#  27  B365Draw                8740 non-null   float64
#  28  B365AwayTeam            8740 non-null   float64
#  29  B365Over2.5Goals        3283 non-null   float64
#  30  B365Under2.5Goals       3283 non-null   float64
#  31  MarketMaxHomeTeam       2280 non-null   float64
#  32  MarketMaxDraw           2280 non-null   float64
#  33  MarketMaxAwayTeam       2280 non-null   float64
#  34  MarketAvgHomeTeam       2280 non-null   float64
#  35  MarketAvgDraw           2280 non-null   float64
#  36  MarketAvgAwayTeam       2280 non-null   float64
#  37  MarketMaxOver2.5Goals   2280 non-null   float64
#  38  MarketMaxUnder2.5Goals  2280 non-null   float64
#  39  MarketAvgOver2.5Goals   2280 non-null   float64
#  40  MarketAvgUnder2.5Goals  2280 non-null   float64
#  41  HomeTeamPoints          12160 non-null  int64
#  42  AwayTeamPoints          12160 non-null  int64
# dtypes: float64(29), int64(5), object(9)
# memory usage: 4.0+ MB
#           MatchWeek  FullTimeHomeTeamGoals  FullTimeAwayTeamGoals  \
# count  12160.000000           12160.000000           12160.000000
# mean      19.089967               1.532648               1.164885
# std       11.046402               1.309152               1.148000
# min        1.000000               0.000000               0.000000
# 25%       10.000000               1.000000               0.000000
# 50%       19.000000               1.000000               1.000000
# 75%       28.000000               2.000000               2.000000
# max       41.000000               9.000000               9.000000
#
#        HalfTimeHomeTeamGoals  HalfTimeAwayTeamGoals  HomeTeamShots  \
# count           11400.000000           11400.000000    9500.000000
# mean                0.691228               0.511754      13.611053
# std                 0.840313               0.731435       5.347822
# min                 0.000000               0.000000       0.000000
# 25%                 0.000000               0.000000      10.000000
# 50%                 0.000000               0.000000      13.000000
# 75%                 1.000000               1.000000      17.000000
# max                 5.000000               5.000000      43.000000
#
#        AwayTeamShots  HomeTeamShotsOnTarget  AwayTeamShotsOnTarget  \
# count    9500.000000            9500.000000            9500.000000
# mean       10.803263               5.980105               4.695053
# std         4.700564               3.266801               2.749988
# min         0.000000               0.000000               0.000000
# 25%         7.000000               4.000000               3.000000
# 50%        10.000000               6.000000               4.000000
# 75%        14.000000               8.000000               6.000000
# max        37.000000              24.000000              20.000000
#
#        HomeTeamCorners  ...  MarketMaxAwayTeam  MarketAvgHomeTeam  \
# count      9500.000000  ...        2280.000000        2280.000000
# mean          6.036947  ...           5.055421           2.955364
# std           3.109099  ...           5.186743           2.167925
# min           0.000000  ...           1.170000           1.070000
# 25%           4.000000  ...           2.250000           1.650000
# 50%           6.000000  ...           3.310000           2.290000
# 75%           8.000000  ...           5.600000           3.330000
# max          20.000000  ...          50.000000          18.090000
#
#        MarketAvgDraw  MarketAvgAwayTeam  MarketMaxOver2.5Goals  \
# count    2280.000000        2280.000000            2280.000000
# mean        4.308329           4.592294               1.831908
# std         1.375207           4.176966               0.287607
# min         2.970000           1.150000               1.210000
# 25%         3.500000           2.180000               1.630000
# 50%         3.830000           3.185000               1.810000
# 75%         4.560000           5.295000               2.020000
# max        12.850000          37.570000               2.880000
#
#        MarketMaxUnder2.5Goals  MarketAvgOver2.5Goals  MarketAvgUnder2.5Goals  \
# count             2280.000000            2280.000000             2280.000000
# mean                 2.296991               1.769566                2.202259
# std                  0.488752               0.266762                0.449748
# min                  1.510000               1.190000                1.470000
# 25%                  1.950000               1.570000                1.880000
# 50%                  2.190000               1.750000                2.110000
# 75%                  2.520000               1.940000                2.410000
# max                  5.060000               2.690000                4.540000
#
#        HomeTeamPoints  AwayTeamPoints
# count    12160.000000    12160.000000
# mean         1.627303        1.118339
# std          1.313476        1.263230
# min          0.000000        0.000000
# 25%          0.000000        0.000000
# 50%          1.000000        1.000000
# 75%          3.000000        3.000000
# max          3.000000        3.000000
#
# [8 rows x 34 columns]

# %%
# analyse missing values
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# Time                      9880
# MarketMaxHomeTeam         9880
# MarketAvgOver2.5Goals     9880
# MarketMaxUnder2.5Goals    9880
# MarketMaxOver2.5Goals     9880
# MarketAvgAwayTeam         9880
# MarketAvgDraw             9880
# MarketAvgHomeTeam         9880
# MarketMaxAwayTeam         9880
# MarketMaxDraw             9880
# MarketAvgUnder2.5Goals    9880
# B365Under2.5Goals         8877
# B365Over2.5Goals          8877
# B365HomeTeam              3420
# B365Draw                  3420
# B365AwayTeam              3420
# HomeTeamCorners           2660
# Referee                   2660
# HomeTeamShots             2660
# AwayTeamShots             2660
# HomeTeamShotsOnTarget     2660
# AwayTeamShotsOnTarget     2660
# HomeTeamFouls             2660
# AwayTeamCorners           2660
# AwayTeamFouls             2660
# HomeTeamRedCards          2660
# AwayTeamYellowCards       2660
# HomeTeamYellowCards       2660
# AwayTeamRedCards          2660
# HalfTimeHomeTeamGoals      760
# HalfTimeResult             760
# HalfTimeAwayTeamGoals      760
# dtype: int64
